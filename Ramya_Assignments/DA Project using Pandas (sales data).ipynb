# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\ramya\Downloads\DA Project using Pandas(sales data)\sales-data.csv")

# %%
df
# Out:
#         Unnamed: 0  Order ID                     Product  Quantity Ordered  \
# 0                0    176558        USB-C Charging Cable                 2
# 1                2    176559  Bose SoundSport Headphones                 1
# 2                3    176560                Google Phone                 1
# 3                4    176560            Wired Headphones                 1
# 4                5    176561            Wired Headphones                 1
# ...            ...       ...                         ...               ...
# 185945      186845    259353      AAA Batteries (4-pack)                 3
# 185946      186846    259354                      iPhone                 1
# 185947      186847    259355                      iPhone                 1
# 185948      186848    259356      34in Ultrawide Monitor                 1
# 185949      186849    259357        USB-C Charging Cable                 1
#
# ...

# %%
df['Sales']=df['Quantity Ordered']*df['Price Each']

# %%
df
# Out:
#         Unnamed: 0  Order ID                     Product  Quantity Ordered  \
# 0                0    176558        USB-C Charging Cable                 2
# 1                2    176559  Bose SoundSport Headphones                 1
# 2                3    176560                Google Phone                 1
# 3                4    176560            Wired Headphones                 1
# 4                5    176561            Wired Headphones                 1
# ...            ...       ...                         ...               ...
# 185945      186845    259353      AAA Batteries (4-pack)                 3
# 185946      186846    259354                      iPhone                 1
# 185947      186847    259355                      iPhone                 1
# 185948      186848    259356      34in Ultrawide Monitor                 1
# 185949      186849    259357        USB-C Charging Cable                 1
#
# ...

# %%
df1=df.groupby('Month')['Sales']

# %%
print(df1)

# %%
Which city sold the most products

# %%
s=df.groupby('City').aggregate('count')

# %%
s
# Out:
#                    Unnamed: 0  Order ID  Product  Quantity Ordered  \
# City
# Atlanta  (GA)           14881     14881    14881             14881
# Austin  (TX)             9905      9905     9905              9905
# Boston  (MA)            19934     19934    19934             19934
# Dallas  (TX)            14820     14820    14820             14820
# Los Angeles  (CA)       29605     29605    29605             29605
#
#                    Price Each  Order Date  Purchase Address  Month  sales  \
# City
# Atlanta  (GA)           14881       14881             14881  14881  14881
# Austin  (TX)             9905        9905              9905   9905   9905
# Boston  (MA)            19934       19934             19934  19934  19934
# Dallas  (TX)            14820       14820             14820  14820  14820
# Los Angeles  (CA)       29605       29605             29605  29605  29605
#
#                    Sales
# City
# Atlanta  (GA)      14881
# Austin  (TX)        9905
# ...
